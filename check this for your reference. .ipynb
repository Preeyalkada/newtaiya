# %%
import requests

# %%
r = requests.get("https://etenders.gov.in/eprocure/app")

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
print(r.content)
# Out:
# b'<head>\r\n\t<base target="_self">\r\n\t<title>Government eProcurement System</title>\r\n</head>\r\n<!-- BEGIN: HEADER -->\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<!-- Application: null -->\n<!-- Page: Home -->\n<!-- Generated: Sun May 14 15:19:56 IST 2023 -->\n<html>\n<head>\n<meta name="generator" content="Tapestry Application Framework, version 4.1.6-SNAPSHOT" />\n<meta http-equiv="Content-Type" content="text/html;charset=UTF-8" />\n<title>eProcurement System</title>\n<script type="text/javascript">djConfig = {"baseRelativePath":"/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2F","preventBackButtonFix":false,"parseWidgets":false,"locale":"en-us"} </script>\n\n<script type="text/javascript" src="/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2Fdojo.js"></script><script type="text/javascript" src="/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2Fdojo2.js"></script>\n<script type="text/javascript">\ndojo.registerModulePath("tapestry", "/eprocure/app?service=asset&path=%2Ftapestry-4.1.6%2F");\n</script>\n<script type="text/javascript" src="/eprocure/app?service=asset&path=%2Ftapestry-4.1.6%2Fcore.js"></script>\n<script type="text/javascript">\ndojo.require("tapestry.namespace");\ntapestry.requestEncoding=\'UTF-8\';\n</script>\n<link rel="stylesheet" type="text/css" href="/eprocure/css/nicgep_web_style.css" />\n</head>\r\n<head>\r\n<meta http-equiv="Pragma" content="no-cache">\r\n<meta http-equiv="no-cache">\r\n<meta http-equiv="Expires" content="-1">\r\n<meta http-equiv="Cache-Control" content="no-cache">\r\n<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\r\n<link rel="shortcut icon" href="images/nation.ico" ></link>\r\n<!-- Javascript -->\r\n<script language="JavaScript" type="text/JavaScript" src="includes/evaluator.js"></script>\r\n<script language="javascript" src="includes/MessageDigest.js" ></script>\r\n<script language="JavaScript" type="text/JavaScript" src="includes/dialog/dialog_box.js"></script>\r\n<!-- End -->\r\n<noscript>\r\n\t<meta http-equiv="Refresh" content="2;url=https://etenders.gov.in/eprocure/app?page=ErrorNotice&amp;service=page" id="Any"></meta> \r\n</noscript>\r\n<script language="JavaScript" type="text/JavaScript">\r\n<!--\r\n\tfunction MM_swapImgRestore() { //v3.0\r\n\t  var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;\r\n\t}\r\n\t\r\n\tfunction MM_preloadImages() { //v3.0\r\n\t  var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();\r\n\t    var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)\r\n\t    if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}\r\n\t}\r\n\t\r\n\tfunction MM_findObj(n, d) { //v4.01\r\n\t  var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {\r\n\t    d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}\r\n\t  if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];\r\n\t  for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);\r\n\t  if(!x && d.getElementById) x=d.getElementById(n); return x;\r\n\t}\r\n\t\r\n\tfunction MM_swapImage() { //v3.0\r\n\t  var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)\r\n\t   if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}\r\n\t}\r\n//-->\r\n</script>\r\n</head>\r\n\r\n\n<body onLoad="MM_preloadImages(\'images/homeb.png\',\'images/contactb.png\',\'images/sitemapb.png\')" onunload="" onpageshow="if (event.persisted) noBack();" id="Body">\n\r\n\t\r\n\t<script type="text/javascript">\r\n\r\n\tif(navigator.appName == \'Microsoft Internet Explorer\')\r\n\t{\r\n\tdocument.onkeydown = fnCheckKeysMIE;\r\n\t}\r\n\telse if(navigator.appName == \'Netscape\')\r\n\t{\r\n\tdocument.onkeydown = fnCheckKeysNMF;\r\n\t}\r\n\t\r\n\tfunction fnCheckKeysNMF(event)\r\n\t ...

# %%
import requests
from bs4 import BeautifulSoup as bs
import csv

 
URL = "https://etenders.gov.in/eprocure/app"
req  = requests.get(URL)

soup = bs(req.content, 'html.parser')
 
#title = soup.title.text
title = soup.body
print(title)
#titles = soup.find_all('div', attrs={'class', 'head'})
titles_list = []
 
count = 1
for a in title:
    d = {}
    d['Title Number'] = f'Title {count}'
    d['Title Name'] = a.text
    count += 1
    titles_list.append(d)
 
filename = 'titles2.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['Title Number','Title Name'])
    w.write()
     
    w.writerows(titles_list)
# Out:
# <body id="Body" onload="MM_preloadImages('images/homeb.png','images/contactb.png','images/sitemapb.png')" onpageshow="if (event.persisted) noBack();" onunload="">
# <script type="text/javascript">
#
# 	if(navigator.appName == 'Microsoft Internet Explorer')
# 	{
# 	document.onkeydown = fnCheckKeysMIE;
# 	}
# 	else if(navigator.appName == 'Netscape')
# 	{
# 	document.onkeydown = fnCheckKeysNMF;
# 	}
#
# 	function fnCheckKeysNMF(event)
# 	{
#
# 	var e=event? event : window.event;
# 	var event_element=e.target? e.target : e.srcElement;
#
# 	if (event.ctrlKey && (event.keyCode==78 || event.keyCode==84 || event.which==78 || event.which==84))
# 	{
# 	return false;
# 	}
#
# 	if (event.altKey && (event.keyCode==37 || event.which==37))
# 	{
# 	return false;
# 	}
#
# 	if (event.keyCode==8 && (event_element.tagName != 'INPUT' && event_element.tagName != 'TEXTAREA'))
# 	{
# 	return false;
# 	}
#
# 	}
#
# 	function fnCheckKeysMIE()
# 	{
#
# 	var e=event? event : window.event;
# 	var event_element=e.target? e.target : e.srcElement;
#
# 	if (event.ctrlKey && (event.keyCode==78 || event.keyCode==84 || event.which==78 || event.which==84))
# 	{
# 	return false;
# 	}
#
# 	if (event.altKey && (event.keyCode==37 || event.which==37))
# 	{
# 	return false;
# 	}
#
# 	if (event.keyCode==8 && (event_element.tagName != 'INPUT' && event_element.tagName != 'TEXTAREA'))
# 	{
# 	return false;
# 	}
#
# 	}
#
# 	window.history.forward();
# 	function noBack(){ window.history.forward(); }
#
# 	</script>
# <table align="center" bgcolor="#FFFFFF" border="0" cellpadding="0" cellspacing="0" height="100%" width="1004">
# <tr>
# <td height="40" valign="top">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="1000">
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" height="22" id="Menu" width="100%">
# <td align="right" class="date" height="22" style="background-color:#BE5825;" width="210"><a class="Menu" href="/eprocure/app?page=WebScreenReaderAccess&amp;service=page" id="link1" name="link1">Screen Reader Access</a>
# </td>
# </table>
# </td>
# </tr>
# <tr>
# <td width="1005"><img alt="Logo" border="0" height="83" id="Any_0" src="images/topban.png" usemap="#Map" width="1005"/></td>
# </tr>
# <tr>
# <td height="1" style="background-color:#D88860;"></td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" height="22" id="Menu" width="100%">
# <tr>
# <td align="center" class="date" height="22" style="background-color:#BE5825;" width="210">
# 				14-May-2023
# 		  </td>
# <td align="center" style="background-color:#D26A35;">
# <span id="If">
# <span id="For">
# <span>
# <a class="Menu" href="/eprocure/app?page=FrontEndAdvancedSearch&amp;service=page" id="link1" name="link1" target="_self" title="Search">Search</a>
# </span>
# <span class="divider1" id="Insert_2">|</span>
# </span><span id="For_0">
# <span>
# <a class="Menu" href="/eprocure/app?page=FrontEndLatestActiveTenders&amp;service=page" id="link1" name="link1" target="_self" title="Active Tenders">Active Tenders</a>
# </span>
# <span class="divider1" id="Insert_2_0">|</span>
# </span><span id="For_1">
# <span>
# <a class="Menu" href="/eprocure/app?page=FrontEndListTendersbyDate&amp;service=page" id="link1" name="link1" target="_self" title="Tenders by Closing Date">Tenders by Closing Date</a>
# </span>
# <span class="divider1" id="Insert_2_1">|</span>
# </span><span id="For_2">
# <span>
# <a class="Menu" href="/eprocure/app?page=FrontEndLatestActiveCorrigendums&amp;service=page" id="link1" name="link1" target="_self" title="Corrigendum">Corrigendum</a>
# </span>
# <span class="divider1" id="Insert_2_2">|</span>
# </span><span id="For_3">
# <span>
# <a class="Menu" href="/eprocure/app?page=ResultOfTenders&amp;service=page" id="link1" name="link1" target="_self" title="Results of Tenders">Results of Tenders</a>
# </span>
# </span>
# </span>
# </td>
# <td style="background-color:#BE5825;" valign="middle" width="215">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td width="28%"><div align="center"><a href="/eprocure/app?service=restart" id="homeLink" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('Image4','','images/homeb.png',1)" page="Home"><img alt="Home" border="0" height="18" name="Image4" src="images/homea.png" width="47"/></a></div></td>
# <td width="40%"><div align="center"><a href="/eprocure/app?page=FrontEndContactUs&amp;service=page" id="PageLink_6" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('Image5','','images/contactb.png',1)"><img alt="Contact Us" border="0" height="18" name="Image5" src="images/contacta.png" width="78"/></a></div></td>
# <td width="32%"><div align="center"><a href="/eprocure/app?page=SiteMap&amp;service=page" id="PageLink_7" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('Image6','','images/sitemapb.png',1)"><img alt="Sitemap" border="0" height="18" name="Image6" src="images/sitemapa.png" width="63"/></a></div></td>
# </tr>
# </table></td>
# </tr>
# </table></td>
# </tr>
# <tr>
# <td>
# <table cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="right" class="notice" width="20"><img alt="Notices" height="16" src="images/notice.png" width="15"> </img></td>
# <td class="notice_strip">
# <marquee align="left" id="gepNotice" onmouseout="this.start();" onmouseover="this.stop();" scrolldelay="200">
# <span>
# 					Government eProcurement System
# 				</span>
# </marquee>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <map name="Map">
# <a coords="43,43,37" href="/eprocure/app?page=Home&amp;service=page" id="PageLink_8" shape="circle"></a>
# </map>
# </td>
# </tr>
# <tr>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" height="100%" width="100%">
# <tr>
# <td class="navigation" width="214"><script language="javascript">
#
# 	// Script to view document in popup
# 	function popup(mylink, windowname)
# 	{
# 		if (! window.focus)return true;
# 		var href;
# 		if (typeof(mylink) == 'string')
# 	 		href=mylink;
# 		else
# 			href=mylink.href;
# 			window.open(href, "Popup", 'location=no, scrollbars=yes, toolbar=no, width=700, height=550, directories=no, menubar=no, resizable=yes, status=no, titlebar=yes');
# 			return false;
# 	}
#
# </script>
# <table cellpadding="0" cellspacing="0" class="left_nav" height="100%" width="100%">
# <tr>
# <td height="10"></td>
# </tr>
# <tr>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" width="214">
# <span id="If_2">
# <tr id="For_5">
# <span id="If_0_4">
# <span id="If_3">
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="https://gepnicreports.gov.in/eprocreports/etenders/" id="GenericLink" target="_blank" title="MIS Reports">MIS Reports</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_6">
# <span id="If_0_5">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=FrontEndTendersByLocation&amp;service=page" id="PageLink" target="_self" title="Tenders by Location">Tenders by Location</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_7">
# <span id="If_0_6">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=FrontEndTendersByOrganisation&amp;service=page" id="PageLink_0" target="_self" title="Tenders by Organisation">Tenders by Organisation</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_8">
# <span id="If_0_7">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=FrontEndTendersByClassification&amp;service=page" id="PageLink_1" target="_self" title="Tenders by Classification">Tenders by Classification</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_9">
# <span id="If_0_8">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=FrontEndTendersInArchive&amp;service=page" id="PageLink_2" target="_self" title="Tenders in Archive">Tenders in Archive</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_10">
# <span id="If_0_9">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=WebTenderStatusLists&amp;service=page" id="PageLink_3" target="_self" title="Tenders Status">Tenders Status</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_11">
# <span id="If_0_10">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=WebCancelledTenderLists&amp;service=page" id="PageLink_4" target="_self" title="Cancelled/Retendered">Cancelled/Retendered</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_12">
# <span id="If_0_11">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=StandardBiddingDocuments&amp;service=page" id="PageLink_5" target="_self" title="Downloads">Downloads</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_13">
# <span id="If_0_12">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=FrontEndDebarmentList&amp;service=page" id="PageLink_9" target="_self" title="D">Debarment List</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_14">
# <span id="If_0_13">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=WebAnnouncements&amp;service=page" id="PageLink_10" target="_self" title="Announcements">Announcements</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_15">
# <span id="If_0_14">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=WebAwards&amp;service=page" id="PageLink_11" target="_self" title="Awards">Awards</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_16">
# <span id="If_0_15">
# <span>
# <tr>
# <td align="center" background="images/textbg.png" height="37"><a class="link1" href="/eprocure/app?page=SiteComp&amp;service=page" id="PageLink_12" target="_self" title="Site compatibility">Site compatibility</a></td>
# </tr>
# </span>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# </tr><tr id="For_17">
# </tr><tr id="For_18">
# </tr><tr id="For_19">
# </tr><tr id="For_20">
# </tr>
# <tr>
# <td height="10"></td>
# </tr>
# </span>
# <span id="If_15">
# <tr>
# <td align="center" height="30">
# <table align="center" border="0" cellpadding="0" cellspacing="0" height="114" width="160">
# <tr id="For_22">
# <tr>
# <td height="15" valign="top"><a href="https://gepnic.gov.in" id="GenericLink_0" target="_blank" title="link"><img border="0" height="34" id="Any_1" src="images/Gepnic Logo.png" width="160"/></a></td>
# </tr>
# <tr>
# <td height="10"></td>
# </tr>
# </tr><tr id="For_23">
# <tr>
# <td height="15" valign="top"><a href="http://india.gov.in" id="GenericLink_0_0" target="_blank" title="National Portal of India - External Link that open in a new window"><img border="0" height="34" id="Any_2" src="images/indiagovin.png" width="160"/></a></td>
# </tr>
# <tr>
# <td height="10"></td>
# </tr>
# </tr><tr id="For_24">
# <tr>
# <td height="15" valign="top"><a href="https://gem.gov.in" id="GenericLink_0_1" target="_blank" title="Government e-Marketing of India - External link that opens in a new window"><img border="0" height="34" id="Any_3" src="images/gem.png" width="160"/></a></td>
# </tr>
# <tr>
# <td height="10"></td>
# </tr>
# </tr><tr id="For_25">
# <tr>
# <td height="15" valign="top"><a href="http://eprocure.gov.in/cppp" id="GenericLink_0_2" target="_blank" title="Central Public Procurement Portal - External Link that opens in a new Window"><img border="0" height="34" id="Any_4" src="images/cppp-img.png" width="160"/></a></td>
# </tr>
# <tr>
# <td height="10"></td>
# </tr>
# </tr>
# </table>
# </td>
# </tr>
# </span>
# <tr>
# <td align="center" height="30"> </td>
# </tr>
# </table>
# </td>
# </tr>
# </table></td>
# <td class="page_content" valign="top">
# <!-- Page content starts here -->
# <script language="javascript">
# 	var delayTime=500;
# 	var marqueeSpeed=1;
# 	var pauseTime=1 ;
# 	var copySpeed=marqueeSpeed;
# 	var pauseSpeed=(pauseTime==0)? copySpeed: 0;
# 	var actualHeight='';
#
# 	function ScrollMarquee()
# 	{
# 		if (parseInt(crossMarquee.style.top)>(actualHeight*(-1)+8))
# 			crossMarquee.style.top=parseInt(crossMarquee.style.top)-copySpeed+"px" ;
# 		else
# 			crossMarquee.style.top=parseInt(marqueeheight)+8+"px";
# 	}
#
# 	function InitializeMarquee()
# 	{
# 		crossMarquee=document.getElementById("vmarquee");
# 		crossMarquee.style.top=0;
# 		marqueeheight=document.getElementById("marqueecontainer").offsetHeight;
# 		actualHeight=crossMarquee.offsetHeight;
# 		if (window.opera || navigator.userAgent.indexOf("Netscape/7")!=-1)
# 		{
# 			crossMarquee.style.height=marqueeheight+"px";
# 			crossMarquee.style.overflow="scroll";
# 			return;
# 		}
# 		setTimeout('lefttime=setInterval("ScrollMarquee()",30)', delayTime);
# 	}
#
# 	if (window.addEventListener)
# 		window.addEventListener("load", InitializeMarquee, false);
# 	else if (window.attachEvent)
# 		window.attachEvent("onload", InitializeMarquee);
# 	else if (document.getElementById)
# 		window.onload=InitializeMarquee;
#
#
# 	// Corrigendum
# 	var delayTime1=500;
# 	var marqueeSpeed1=1;
# 	var pauseTime1=1 ;
# 	var copySpeed1=marqueeSpeed1;
# 	var pauseSpeed1=(pauseTime1==0)? copySpeed1: 0;
# 	var actualHeight1='';
#
# 	function ScrollMarquee1()
# 	{
# 		if (parseInt(crossMarquee1.style.top)>(actualHeight1*(-1)+8))
# 		crossMarquee1.style.top=parseInt(crossMarquee1.style.top)-copySpeed1+"px" ;
# 		else
# 		crossMarquee1.style.top=parseInt(marqueeheight1)+8+"px";
# 	}
#
# 	function InitializeMarquee1()
# 	{
# 		crossMarquee1=document.getElementById("vmarquee1");
# 		crossMarquee1.style.top=0;
# 		marqueeheight1=document.getElementById("marqueecontainer1").offsetHeight;
# 		actualHeight1=crossMarquee1.offsetHeight ;
# 		if (window.opera || navigator.userAgent.indexOf("Netscape/7")!=-1)
# 		{
# 			crossMarquee1.style.height=marqueeheight1+"px";
# 			crossMarquee1.style.overflow="scroll";
# 			return;
# 		}
# 		setTimeout('lefttime=setInterval("ScrollMarquee1()",30)', delayTime1);
# 	}
#
# 	if (window.addEventListener)
# 	window.addEventListener("load", InitializeMarquee1, false);
# 	else if (window.attachEvent)
# 	window.attachEvent("onload", InitializeMarquee1);
# 	else if (document.getElementById)
# 	window.onload=InitializeMarquee1;
#
# 	// Corrigendum
# 	var delayTime2=500;
# 	var marqueeSpeed2=1;
# 	var pauseTime2=1 ;
# 	var copySpeed2=marqueeSpeed2;
# 	var pauseSpeed2=(pauseTime2==0)? copySpeed2: 0;
# 	var actualHeight2='';
#
# 	function ScrollMarquee2()
# 	{
# 		if (parseInt(crossMarquee2.style.top)>(actualHeight2*(-1)+8))
# 		crossMarquee2.style.top=parseInt(crossMarquee2.style.top)-copySpeed2+"px" ;
# 		else
# 		crossMarquee2.style.top=parseInt(marqueeheight2)+8+"px";
# 	}
#
#
# 	function InitializeMarquee2()
# 	{
# 		crossMarquee2=document.getElementById("vmarquee2");
# 		crossMarquee2.style.top=0;
# 		marqueeheight2=document.getElementById("marqueecontainer2").offsetHeight;
# 		actualHeight2=crossMarquee2.offsetHeight ;
# 		if (window.opera || navigator.userAgent.indexOf("Netscape/7")!=-1)
# 		{
# 			crossMarquee2.style.height=marqueeheight2+"px";
# 			crossMarquee2.style.overflow="scroll";
# 			return;
# 		}
# 		setTimeout('lefttime=setInterval("ScrollMarquee2()",30)', delayTime2);
# 	}
#
# 	if (window.addEventListener)
# 	window.addEventListener("load", InitializeMarquee2, false);
# 	else if (window.attachEvent)
# 	window.attachEvent("onload", InitializeMarquee2);
# 	else if (document.getElementById)
# 	window.onload=InitializeMarquee2;
#
# 	// Corrigendum
# 	var delayTime3=500;
# 	var marqueeSpeed3=1;
# 	var pauseTime3=1 ;
# 	var copySpeed3=marqueeSpeed3;
# 	var pauseSpeed3=(pauseTime3==0)? copySpeed3: 0;
# 	var actualHeight3='';
#
# 	function ScrollMarquee3()
# 	{
# 		if (parseInt(crossMarquee3.style.top)>(actualHeight3*(-1)+8))
# 		crossMarquee3.style.top=parseInt(crossMarquee3.style.top)-copySpeed3+"px" ;
# 		else
# 		crossMarquee3.style.top=parseInt(marqueeheight3)+8+"px";
# 	}
#
#
# 	function InitializeMarquee3()
# 	{
# 		crossMarquee3=document.getElementById("vmarquee3");
# 		crossMarquee3.style.top=0;
# 		marqueeheight3=document.getElementById("marqueecontainer3").offsetHeight;
# 		actualHeight3=crossMarquee3.offsetHeight ;
# 		if (window.opera || navigator.userAgent.indexOf("Netscape/7")!=-1)
# 		{
# 			crossMarquee3.style.height=marqueeheight3+"px";
# 			crossMarquee3.style.overflow="scroll";
# 			return;
# 		}
# 		setTimeout('lefttime=setInterval("ScrollMarquee3()",30)', delayTime3);
# 	}
#
# 	if (window.addEventListener)
# 	window.addEventListener("load", InitializeMarquee3, false);
# 	else if (window.attachEvent)
# 	window.attachEvent("onload", InitializeMarquee3);
# 	else if (document.getElementById)
# 	window.onload=InitializeMarquee3;
#
# </script>
# <script src="js/jquery.min.js"></script>
# <script src="js/nicci.js"></script>
# <script language="JavaScript" type="text/javascript">
#        $(document).ready(function() {
#             loadnicci('ContentNicci', 'vDOWF0A7F0DUpjzp');
#         });
#     </script>
# <div id="ContentNicci"></div>
# <!--
# 		Page content
# 	 -->
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td height="40">
# <table cellpadding="0" cellspacing="2" width="100%">
# <tr>
# <td class="pageheader">Welcome to eProcurement System</td>
# </tr>
# <tr>
# <td class="page_desc">The eProcurement System enables the Tenderers to download the Tender Schedule free of cost and then submit the bids online through this portal.</td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td class="td_space"> </td>
# </tr>
# <span id="If_16">
# <tr>
# <td height="25%">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center">
# <a href="https://eprocure.gov.in/eprocdashboard/" id="hleproc_dash" target="_blank" title="CPPP Dashboard">
# <img alt="app-dashboard" border="0" id="eproc_dash" src="images/app-dashboard.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=gov.nic.eproc&amp;hl=en" id="hleproc_playstore" target="_blank" title="Mobile App">
# <img alt="playstore" border="0" id="eproc_playstore" src="images/playstore.png"/>
# </a>
# <a href="https://itunes.apple.com/in/app/gepnic/id1330902501?mt=8" id="hleproc_playstore" target="_blank" title="Mobile App">
# <img alt="playstore" border="0" id="eproc_playstore" src="images/appstore.png"/>
# </a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </span>
# <tr>
# <td height="25">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <span id="If_0_20">
# <tr>
# <td width="31%"><img alt="Latest Tenders" height="27" src="images/latestenders_title.png" width="159"/>
# <td height="10" width="69%"> </td>
# </td></tr>
# <tr>
# <td colspan="2" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" class="list_table" width="100%">
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr class="list_header">
# <td align="left" width="30%">Tender Title</td>
# <td align="left" width="20%">Reference No</td>
# <td align="left" width="25%">Closing Date</td>
# <td align="left" width="25%">Bid Opening Date</td>
# </tr>
# <tr>
# <td colspan="4" width="100%">
# <div id="marqueecontainer" onmouseout="copySpeed=marqueeSpeed" onmouseover="copySpeed=pauseSpeed" style="width:560px;">
# <div id="vmarquee" style="LEFT:4px;POSITION:absolute; TOP:2px; WIDTH:560px;">
# <span id="If_17">
# <table border="0" cellpadding="0" cellspacing="0" id="activeTenders" width="100%">
# <tr class="even" id="informal">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SZ6goJ%2FpOZ0DaaS03Qhmjwg%3D%3D" id="DirectLink">1. OFC laying for rehabilitation of 42Km existing OFC route as per requirement of SSA for providing backhaul media and  3.5Km fronthaul media to proposed category 2 BTS sites under 4G saturation project in Akola SSA</a></td>
# <td width="20%">MHATI/17/24/7/2023-PLG/364322/ Akola4G/8 Dtd13.5.</td>
# <td width="25%">02-Jun-2023 03:00 PM</td>
# <td width="25%">03-Jun-2023 03:00 PM</td>
# </tr>
# <tr class="odd" id="informal_0">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=Skg3kbKuPeThWBwtB0N4n7A%3D%3D" id="DirectLink_0">2. N-2/383/JLN01 /4G/OFC laying/Jalna SSA/ 23-24   Dated 13/05/2023   </a></td>
# <td width="20%">N-2/383/JLN01 /4G/OFC laying/Jalna SSA/ 23-24   Da</td>
# <td width="25%">02-Jun-2023 01:00 PM</td>
# <td width="25%">03-Jun-2023 03:00 PM</td>
# </tr>
# <tr class="even" id="informal_1">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SVsFpqsTXDN%2BhO2X0h7i%2Few%3D%3D" id="DirectLink_1">3. Tender for Cement Packing Loading Stacking of Cement packed bags in trucks/ tractors and  other   miscellaneous jobs in Packing plant at Rajban Plant site</a></td>
# <td width="20%">RCF/MECH/PPContract/2023</td>
# <td width="25%">03-Jun-2023 06:55 PM</td>
# <td width="25%">05-Jun-2023 11:00 AM</td>
# </tr>
# <tr class="odd" id="informal_2">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SEQMkkpKCdTa5SxR4xGjfxg%3D%3D" id="DirectLink_2">4. Procurement of Kiln Shell Cooling Fan at Bokajan Cement Factory of CCI</a></td>
# <td width="20%">BKJ/MM/Prod-2249 /23-24</td>
# <td width="25%">06-Jun-2023 03:00 PM</td>
# <td width="25%">07-Jun-2023 03:00 PM</td>
# </tr>
# <tr class="even" id="informal_3">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=S0ruAJDEafKT4PDcTyn7aKA%3D%3D" id="DirectLink_3">5. Annual rate contract for hiring of 120 ton (Min.) capacity crane for executing different types of lifting jobs in NFL, Panipat unit.</a></td>
# <td width="20%">NFP/M/WS/CRANE/2023-24</td>
# <td width="25%">12-Jun-2023 03:00 PM</td>
# <td width="25%">13-Jun-2023 03:30 PM</td>
# </tr>
# <tr class="odd" id="informal_4">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=Sfy9dqrEdlQSBddaFm9vkug%3D%3D" id="DirectLink_4">6. Comprehensive maintenance of  Window / Split AC units,  AFD system and operation, monitoring and general maintenance of different electro-mechanical  services at  TE building  Citycenter, OA-Durgapur of Asansol BA.</a></td>
# <td width="20%">11/BSNL ED-ASL/2023-24 dated 13.05.2023</td>
# <td width="25%">20-May-2023 03:00 PM</td>
# <td width="25%">22-May-2023 01:00 PM</td>
# </tr>
# <tr class="even" id="informal_5">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SqTX5Z8qs7qkEsjea992tKw%3D%3D" id="DirectLink_5">7. CAMC of Tubewells installed in the various Municipal Parks under Shahdara (North) Zone.</a></td>
# <td width="20%">EE(E)-I/SHN/MCD/23-24/TC-03/1</td>
# <td width="25%">22-May-2023 01:00 PM</td>
# <td width="25%">23-May-2023 02:00 PM</td>
# </tr>
# <tr class="odd" id="informal_6">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SCH0wz2ikfw%2B%2B5mhf%2Fm5M%2FA%3D%3D" id="DirectLink_6">8. RC for Repairing of RC for Repairing of Submersible Dewatering Pump at IGSTPP Jharli Jhajjar Haryana</a></td>
# <td width="20%">CRN-3932</td>
# <td width="25%">29-May-2023 02:00 PM</td>
# <td width="25%">30-May-2023 03:00 PM</td>
# </tr>
# <tr class="even" id="informal_7">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=S3lhFhSVRZAR4MR1Opri9dg%3D%3D" id="DirectLink_7">9. Repairs of Damaged  patches of water proofing treatment in the terrace and Structural repair works in Main TE Building at Villupuram.</a></td>
# <td width="20%">07 /BSNL/CD/ABM/CHN/2023-24</td>
# <td width="25%">22-May-2023 05:00 PM</td>
# <td width="25%">23-May-2023 04:00 PM</td>
# </tr>
# <tr class="odd" id="informal_8">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SZCyosVIYB0Z2BFAEcFYzgQ%3D%3D" id="DirectLink_8">10. Contract for Supply, Installation and Commissioning of Long Travel Micro Mechanism of 100/20T EOT Crane at RGPPL site</a></td>
# <td width="20%">231300026</td>
# <td width="25%">29-May-2023 03:00 PM</td>
# <td width="25%">30-May-2023 03:30 PM</td>
# </tr>
# </table>
# </span>
# </div>
# </div>
# </td>
# </tr>
# <tr class="list_header">
# <td class="link2" colspan="3"><span class="Clickhere">  Latest Tenders updates every 15 mins.</span></td>
# <span id="If_18">
# <td>   <a class="Clickhere" href="/eprocure/app?page=FrontEndLatestActiveTenders&amp;service=page" id="PageLink_13" title="More Tenders">More...</a></td>
# </span>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td colspan="2" height="27" valign="top"> </td>
# </tr>
# <tr>
# <td colspan="2" height="27" valign="top"><img alt="Latest Corrigendums" height="27" src="images/latestcorrigendums_title.png" width="209"/></td>
# </tr>
# <tr>
# <td colspan="2" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" class="list_table" width="100%">
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr class="list_header">
# <td align="left" width="30%">Corrigendum Title</td>
# <td align="left" width="20%">Reference No</td>
# <td align="left" width="25%">Closing Date</td>
# <td align="left" width="25%">Bid Opening Date</td>
# </tr>
# <tr>
# <td colspan="4" width="100%">
# <div id="marqueecontainer1" onmouseout="copySpeed1=marqueeSpeed1" onmouseover="copySpeed1=pauseSpeed1" style="width:560px;">
# <div id="vmarquee1" style="LEFT:4px;POSITION:absolute; TOP:2px; WIDTH:560px;">
# <span id="If_19">
# <table border="0" cellpadding="0" cellspacing="0" id="activeCorrigendums" width="100%">
# <tr class="even" id="informal_9">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=S38qRsvb6BE8PD0ZnPDqAyw%3D%3D" id="DirectLink_9">1. Bid Auto Extn Corrigendum</a></td>
# <td width="20%">HITES/PCD/NCI-AIIMS/48/22-23</td>
# <td width="25%">17-May-2023 02:00 PM</td>
# <td width="25%">18-May-2023 02:30 PM</td>
# </tr>
# <tr class="odd" id="informal_10">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SxN44ma4uz11IiUVK0tRIHA%3D%3D" id="DirectLink_10">2. Bid Auto Extn Corrigendum</a></td>
# <td width="20%">HITES/PCD/NCI-AIIMS/48/22-23</td>
# <td width="25%">17-May-2023 02:00 PM</td>
# <td width="25%">18-May-2023 02:30 PM</td>
# </tr>
# <tr class="even" id="informal_11">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SyidiDqBIHH274g%2BDZBvJ6w%3D%3D" id="DirectLink_11">3. Corrigendum of SD</a></td>
# <td width="20%">06/BSNL ED-ASL/2023-24 dated 12.05.2023</td>
# <td width="25%">18-May-2023 03:00 PM</td>
# <td width="25%">20-May-2023 01:00 PM</td>
# </tr>
# <tr class="odd" id="informal_12">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SuiC77vynUKhyjID7dVj6HQ%3D%3D" id="DirectLink_12">4. Corrigendum of SD</a></td>
# <td width="20%">05/BSNL ED-ASL/2023-24 dated 12.05.2023</td>
# <td width="25%">18-May-2023 03:00 PM</td>
# <td width="25%">20-May-2023 01:00 PM</td>
# </tr>
# <tr class="even" id="informal_13">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SNjhqnu%2FrgkjamVVAJmwEZQ%3D%3D" id="DirectLink_13">5. Corrigendum</a></td>
# <td width="20%">UPZ/361/STPI/BAR/23-24/146</td>
# <td width="25%">16-May-2023 03:00 PM</td>
# <td width="25%">17-May-2023 03:00 PM</td>
# </tr>
# <tr class="odd" id="informal_14">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SdMBR%2BUjoC4c5Qix5z5BG0w%3D%3D" id="DirectLink_14">6. Date Extension</a></td>
# <td width="20%">05/BSNL/BCD-1/2023-24</td>
# <td width="25%">15-May-2023 06:00 PM</td>
# <td width="25%">17-May-2023 12:00 PM</td>
# </tr>
# <tr class="even" id="informal_15">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SF3T4Xr2qkytjWJY38INTrA%3D%3D" id="DirectLink_15">7. Bid Auto Extn Corrigendum</a></td>
# <td width="20%">NIT/23-24/15</td>
# <td width="25%">17-May-2023 06:00 PM</td>
# <td width="25%">18-May-2023 12:30 PM</td>
# </tr>
# <tr class="odd" id="informal_16">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SVqh5mbh3TEUaNHiwyxfxuw%3D%3D" id="DirectLink_16">8. Bid Auto Extn Corrigendum</a></td>
# <td width="20%">NIT/23-24/10</td>
# <td width="25%">16-May-2023 06:00 PM</td>
# <td width="25%">17-May-2023 04:00 PM</td>
# </tr>
# <tr class="even" id="informal_17">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=Sz9ml5SFbhZjhNOGf0kQFPQ%3D%3D" id="DirectLink_17">9. Corrigendum-II</a></td>
# <td width="20%">C-2(b)/RFP/0704/381/2023</td>
# <td width="25%">18-May-2023 11:00 AM</td>
# <td width="25%">18-May-2023 11:00 AM</td>
# </tr>
# <tr class="odd" id="informal_18">
# <td width="30%"><a class="link2" href="/eprocure/app?component=%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=S%2FTzZV4xNlipID7OW0wU%2BBQ%3D%3D" id="DirectLink_18">10. Addendum I</a></td>
# <td width="20%">NHAI/PIU-Gwl/GS/Emergent</td>
# <td width="25%">22-May-2023 11:00 AM</td>
# <td width="25%">23-May-2023 12:00 PM</td>
# </tr>
# </table>
# </span>
# </div>
# </div>
# </td>
# </tr>
# <tr class="list_header">
# <td class="link2" colspan="3">  <span class="Clickhere">  Latest Corrigendum updates every 15 mins.</span></td>
# <span id="If_20">
# <td>   <a class="Clickhere" href="/eprocure/app?page=FrontEndLatestActiveCorrigendums&amp;service=page" id="PageLink_14" title="More Corrigendums">More...</a></td>
# </span>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </span>
# </table>
# </td>
# </tr>
# <tr>
# <td class="td_space"> </td>
# </tr>
# <tr>
# <td align="center" colspan="2" valign="bottom">
# <table border="0" cellpadding="0" cellspacing="0" class="list_table" width="100%">
# <tr class="list_header">
# <td>Certifying Agency</td>
# </tr>
# <tr>
# <td align="center">
# <table border="0" cellpadding="2" cellspacing="2">
# <tr>
# <td>
# <a href="/eprocure/app?component=%24DirectLink_3&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SSTQC_Audit_Report.pdf" id="DirectLink_19">
# <img alt="STQC Logo" height="48" src="images/stqc_logo.png" title="Standardization, Testing and Quality Control" width="47"/>
# </a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <!-- End of Page Content -->
# <!-- Page content ends here -->
# </td>
# <td class="navigation" valign="top" width="215">
# <table cellpadding="0" cellspacing="0">
# <tr>
# <td width="215"> <form action="/eprocure/app" autocomplete="off" id="WebRightMenu_0" method="post">
# <div id="WebRightMenu_0hidden" style="display:none;"><input name="formids" type="hidden" value=""/>
# <input name="seedids" type="hidden" value=""/>
# <input name="component" type="hidden" value="$WebHomeBorder.$WebRightMenu.WebRightMenu"/>
# <input name="page" type="hidden" value="Home"/>
# <input name="service" type="hidden" value="direct"/>
# <input name="session" type="hidden" value="T"/>
# <input name="submitmode" type="hidden" value=""/>
# <input name="submitname" type="hidden" value=""/>
# </div>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="214">
# <tr>
# <td>
# <table align="center" border="0" cellpadding="0" cellspacing="0" height="100" width="210">
# <tr>
# <td valign="top">
# <table align="center" border="0" cellpadding="5" cellspacing="5" width="210">
# <tr>
# <td align="left">
# <a href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.login&amp;page=Home&amp;service=direct&amp;session=T" id="login" style="display:none" title="Login" value="Login"><img align="absmiddle" border="0" src="images/home_login_button_2.png"/></a>
# <noscript>
# <a href="" title="Login"><img align="absmiddle" border="0" src="images/home_login_button_2.png"/> </a>
# </noscript>
# <noscript>
# <p align="justify" style="color:red;">Your browser JavaScript has been disabled. Kindly enable script for further process.</p>
# </noscript>
# </td>
# </tr>
# <tr>
# <td align="left">
# <a class="Clickhere" href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T" id="DirectLink_20" style="display:none">   Online Bidder Enrollment</a>
# <noscript> <span class="Clickhere" style="color: #a03901;" title="Online Bidder Enrollment">  Online Bidder Enrollment</span></noscript>
# </td>
# </tr>
# <tr>
# <td align="left">
# <a class="Clickhere" href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T" id="DirectLink_21" onclick="return openPopUp(this, 'location=no, scrollbars=yes, toolbar=no, width=1004, height=750, directories=no, menubar=no, resizable=yes, status=no, titlebar=yes');" style="display:none" title="Generate / Forgot Password">  Generate / Forgot Password?</a>
# <noscript><span class="Clickhere" style="color: #a03901;" title="Generate / Forgot Password">  Generate / Forgot Password?</span></noscript>
# </td>
# </tr>
# <tr>
# <td align="left">
# <a class="Clickhere" href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.%24DirectLink_1&amp;page=Home&amp;service=direct&amp;session=T" id="DirectLink_22" title="Find My Nodal Officer">  Find My Nodal Officer</a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </form>
# <script>
# 		document.getElementById("login").style.display='block';
# 		var all = document.getElementsByClassName("Clickhere");
# 		for (var i = 0; i < all.length; i++) {
# 			all[i].style.display = 'block';
# 	    }
#     </script>
# </td>
# </tr>
# <span id="If_22">
# <tr>
# <td class="page_notes">Search with ID/Title/Reference no </td>
# </tr>
# <tr>
# <td width="215"><form action="/eprocure/app" id="tenderSearch" method="post">
# <div id="tenderSearchhidden" style="display:none;"><input name="formids" type="hidden" value="If_24,SearchDescription,Go"/>
# <input name="seedids" type="hidden" value="..."/>
# <input name="component" type="hidden" value="$WebHomeBorder.$WebTenderSearch.tenderSearch"/>
# <input name="page" type="hidden" value="Home"/>
# <input name="service" type="hidden" value="direct"/>
# <input name="session" type="hidden" value="T"/>
# <input name="submitmode" type="hidden" value=""/>
# <input name="submitname" type="hidden" value=""/>
# <input name="If_24" type="hidden" value="F"/>
# </div>
# <table align="center" border="0" cellpadding="0" cellspacing="0" height="90" width="210">
# <tr>
# <td> </td>
# </tr>
# <tr align="left">
# </tr>
# <tr>
# <td height="90" valign="top">
# <table align="center" border="0" cellpadding="0" cellspacing="0" height="90" width="213">
# <tr>
# <td background="images/tendersearchbg.png" valign="top">
# <table align="center" border="0" cellpadding="2" cellspacing="2" width="181">
# <tr>
# <td colspan="2" height="25"></td>
# </tr>
# <tr>
# <td class="logintext" width="69"><input class="textbox2" id="SearchDescription" name="SearchDescription" type="text" value=""/></td>
# <td width="98"><div align="center"><input border="0" class="customButton" id="Go" name="Go" title="Min. 3 chars. required for Tender Ref.no/Tender ID/Title" type="submit" value="Go"/></div></td>
# </tr>
# <tr>
# <td align="left" colspan="2" height="29">   <a class="brown_link" href="/eprocure/app?page=FrontEndAdvancedSearch&amp;service=page" id="PageLink_15" title="Advanced Search"><b>Advanced Search</b></a>
# </td>
# </tr>
# </table></td>
# </tr>
# </table></td>
# </tr>
# </table>
# </form></td>
# </tr>
# </span>
# <tr>
# <td width="215"><table align="center" border="0" cellpadding="0" cellspacing="0" width="214">
# <tr valign="top">
# <td colspan="5">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="204">
# <span id="If_25">
# <tr>
# <td>
# <div id="secondcol">
# <div id="menu4">
# <ul>
# <li id="For_27">
# <span>
# <a href="/eprocure/app?page=HelpForContractors&amp;service=page" id="PageLink_16" target="_self" title="Help For Contractors">Help For Contractors</a>
# </span>
# </li><li id="For_28">
# <span>
# <a href="/eprocure/app?page=DSCInfo&amp;service=page" id="PageLink_17" target="_self" title="Information About DSC">Information About DSC</a>
# </span>
# </li><li id="For_29">
# <span id="If_0_24">
# <a href="https://eprocure.gov.in/cppp/hassle_free_bid_submission.pdf" id="GenericLink_1" target="_blank">Guidelines for Hassle Free Bid Submission</a>
# </span>
# </li><li id="For_30">
# <span>
# <a href="/eprocure/app?page=FAQFrontEnd&amp;service=page" id="PageLink_18" target="_self" title="FAQ">FAQ</a>
# </span>
# </li><li id="For_31">
# <span>
# <a href="/eprocure/app?page=FrontFeedback&amp;service=page" id="PageLink_19" target="_self" title="Feedback">Feedback</a>
# </span>
# </li><li id="For_32">
# <span>
# <a href="/eprocure/app?page=BiddersManualKit&amp;service=page" id="PageLink_20" target="_self" title="Bidders Manual Kit">Bidders Manual Kit</a>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </td>
# </tr>
# </span>
# <!-- tr>
# 					<td valign="top">
# 					<div id="secondcol">
# 						<div id="menu4">
# 						  <ul>
# 							<li><span jwcid="@PageLink" page="HelpForContractors">Help For Contractors </span></li>
# 							<li><span jwcid="@PageLink" page="DSCInfo">Information About DSC</span></li>
# 							<li><span jwcid="@PageLink" page="FAQFrontEnd">FAQ</span></li>
# 							<li><span jwcid="@PageLink" page="FrontFeedback">Feedback</span></li>
# 							<li><span jwcid="@DirectLink" listener="listener:showHelpForResources" >Resources Required</span></li>
# 							<li><span jwcid="@PageLink" page="BiddersManualKit">Bidders Manual Kit</span></li>
# 							</ul>
# 						</div>
# 					  </div>
# 					</td>
# 				  </tr-->
# </table>
# </td>
# </tr>
# </table></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td height="40" valign="bottom">
# <table cellpadding="0" cellspacing="0" width="100%">
# <tr style="background-color:#E8E8E8;">
# <td align="center" class="text2" height="25"><b>Visitor No:3791839</b></td>
# </tr>
# <tr style="background-color:#E8E8E8;">
# <td align="center" class="text2" height="25">Contents owned and maintained by concerned Departments in coordination with Finance Department and Information Technology Department, Government of India
# 		 </td>
# </tr>
# <tr style="background-color:#D07141;" valign="top">
# <td>
# <table border="0" cellpadding="1" cellspacing="1" height="22" width="100%">
# <tr class="footer">
# <td align="left" valign="top" width="40%">Designed, Developed and Hosted by<br/> <a class="footerlink" href="http://www.nic.in" target="_blank">National Informatics Centre</a></td>
# <td align="left" width="40%">
# 						 Version : 1.09.18 04-Feb-2023<br/>
# 						(c) 2017 Tenders NIC, All rights reserved.<br/>Site best viewed in IE 10 and above, with a screen resolution 1024 x 768.</td>
# <td align="right" valign="top" width="20%"><a class="footerlink" href="/eprocure/app?page=Disclaimer&amp;service=page" id="PageLink_21">Portal policies</a></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <script type="text/javascript"><!--
# tapestry.addOnLoad(function(e) {
# dojo.require("tapestry.form");tapestry.form.registerForm("WebRightMenu_0");
#
# tapestry.form.registerForm("tenderSearch");
#
# tapestry.form.focusField('SearchDescription');});
# // --></script></body>
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [23], line 26
#      23     titles_list.append(d)
#      25 filename = 'titles2.csv'
# ---> 26 with open(filename, 'w', newline='') as f:
#      27     w = csv.DictWriter(f,['Title Number','Title Name'])
#      28     w.write()
#
# PermissionError: [Errno 13] Permission denied: 'titles2.csv'
